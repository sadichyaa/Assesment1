# %%
import pandas as pd
dataset = pd.read_csv('/content/drive/MyDrive/Assignment1/WHR-2024-5CS037.csv')
dataset.head()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 3. Tasks - To - Do
#
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up Exercises:

# %% [markdown]
# 1. Data Exploration and Understanding:
#
# • Dataset Overview:
#  1. Load the dataset and display the first 10 rows.
#  2. Identify the number of rows and columns in the dataset.
#  3. List all the columns and their data types.

# %%
import pandas as pd
# Load the dataset and preview the first 10 rows.
dataset = pd.read_csv('/content/drive/MyDrive/Assignment1/WHR-2024-5CS037.csv')
dataset.head(10)
# Out:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %%
#Determine the number of rows and columns in the dataset.
dataset.shape
print("Number of rows:", dataset.shape[0])
print("Number of columns:", dataset.shape[1])
# Out:
# Number of rows: 143
# Number of columns: 9

# %%
#Display all columns along with their data types.
dataset.dtypes
# Out:
# Country name                     object
# score                           float64
# Log GDP per capita              float64
# Social support                  float64
# Healthy life expectancy         float64
# Freedom to make life choices    float64
# Generosity                      float64
# Perceptions of corruption       float64
# Dystopia + residual             float64
# dtype: object

# %% [markdown]
# • Basic Statistics:
#  1. Calculate the mean, median, and standard deviation for the Score column.
#  2. Identify the country with the highest and lowest happiness scores.

# %%
import pandas as pd
#Compute the mean, median, and standard deviation of the score column.
mean_score = dataset['score'].mean()
median_score = dataset['score'].median()
std_score = dataset['score'].std()
print("Mean Score:", mean_score)
print("Median Score:", median_score)
print("Standard Deviation of Score:", std_score)
# Out:
# Mean Score: 5.52758041958042
# Median Score: 5.785
# Standard Deviation of Score: 1.1707165099442995

# %%
#Find the country with the highest and lowest happiness score.
max_score_country = dataset.loc[dataset['score'].idxmax()]['Country name']
min_score_country = dataset.loc[dataset['score'].idxmin()]['Country name']
print("Country with Highest happiness Score:", max_score_country)
print("Country with Lowest happiness Score:", min_score_country)
# Out:
# Country with Highest happiness Score: Finland
# Country with Lowest happiness Score: Afghanistan

# %% [markdown]
#  • Missing Values:
#  1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
import pandas as pd
#Inspect the dataset for missing values.
missing_values = dataset.isnull().sum()
print("Missing Values:")
missing_values
# Out:
# Missing Values:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
#  1. Filter the dataset to show only the countries with a Score greater than 7.5.
#  2. For the filtered dataset- Sort the dataset by GDP per Capita in descending order and display the
#  top 10 rows.

# %%
import pandas as pd
#Filter the dataset for countries with a score above 7.5.
filtered_dataset = dataset[dataset['score'] > 7.5]
print("Filtered Dataset(only the countries with a score greater than 7.5):")
filtered_dataset
# Out:
# Filtered Dataset(only the countries with a score greater than 7.5):
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050

# %%
#Sort the dataset by GDP per Capita in descending order and show the top 10 rows.

sorted_dataset = dataset.sort_values(by = 'Log GDP per capita', ascending = False)
print("Top 10 Countries by GDP per Capita:")
sorted_dataset.head(10)
# Out:
# Top 10 Countries by GDP per Capita:
#                  Country name  score  Log GDP per capita  Social support  \
# 7                  Luxembourg  7.122               2.141           1.355
# 16                    Ireland  6.838               2.129           1.390
# 29                  Singapore  6.523               2.118           1.361
# 21       United Arab Emirates  6.733               1.983           1.164
# 8                 Switzerland  7.060               1.970           1.425
# 6                      Norway  7.302               1.952           1.517
# 22              United States  6.725               1.939           1.392
# 85  Hong Kong S.A.R. of China  5.316               1.909           1.184
# 1                     Denmark  7.583               1.908           1.520
# 5                 Netherlands  7.319               1.901           1.462
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# ...

# %% [markdown]
# • Adding New Columns:
#  1. Create a new column called Happiness Category that categorizes countries into three categories
#  based on their Score:
#
#  Low −(Score < 4)
#
#  Medium −(4 ≤ Score ≤ 6)
#
#  High −(Score > 6)

# %%
#dentify categories with a score below 4.
import pandas as pd
import  numpy as np
dataset = pd.read_csv('/content/drive/MyDrive/Assignment1/WHR-2024-5CS037.csv')

dataset['Happiness Category']= np.where(dataset['score'] < 4, 'Low', np.where(dataset['score'] <= 6, 'Medium', 'High'))

#Show the updated DataFrame.
updated_dataset = (dataset[['Country name', 'score', 'Happiness Category']])
updated_dataset.head(143)
# Out:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
#  2. Data Visualizations:
#
#  • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.
#
#  • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.
#
#  • Plot a histogram for the Score column to show its distribution and also interpret.
#
#  • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#Arrange the dataset by 'Score' in descending order and display the top 10 countries with the highest happiness scores.
top_10_happy = dataset.sort_values(by='score', ascending=False).head(10)

#Generate a bar plot.
plt.figure(figsize=(10, 6))
sns.barplot(x='Country name', y='score', data=top_10_happy)
plt.title('Top 10 Happiest Countries by Score')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.show()

# %%
#Create a line plot to visualize the top 10 unhappiest countries based on their Score.


#Sort the dataset by 'Score' in ascending order and select the bottom 10 countries with the lowest happiness scores.
top_10_unhappiest_countries = dataset.sort_values(by='score').head(10)

# generate the line plot.
plt.figure(figsize=(10, 6))
sns.lineplot(x='Country name', y='score', data=top_10_unhappiest_countries, marker='o', color='red')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xticks(rotation=45, ha='right')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.show()

# %%
#Create a histogram for the 'Score' column to visualize its distribution and provide an interpretation of the results.
plt.figure(figsize=(10, 6))
sns.histplot(dataset['score'], bins=10, kde=True)
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

# %%
#Create a scatter plot to visualize the relationship between GDP per Capita and Score.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=dataset, color = 'Green')
plt.title('Scatter Plot: GDP per Capita vs. Score')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Happiness Score')
plt.show()

# %% [markdown]
# 3.2
# Problem - 2- Some Advance Data Exploration Task:

# %% [markdown]
# Task - 1- Setup Task - Preparing the South-Asia Dataset:

# %% [markdown]
#  Steps:
#
#  1. Define the countries in South Asia with a list for example:
#  south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#  "Maldives", "Nepal", "Pakistan", "Srilanka"]
#
#  2. Use the list from step- 1 to filtered the dataset {i.e. filtered out matching dataset from list.}
#
#  3. Save the filtered dataframe as separate CSV files for future use.

# %%
import pandas as pd
#List the countries in South Asia.
south_asian_countries = ["Afghanistan", "Bangladesh", "Bhutan", "India", "Maldives", "Nepal", "Pakistan", "Sri Lanka"]

#Select data from the dataset that corresponds to countries in South Asia.
filtered_dataset = dataset[dataset['Country name'].isin(south_asian_countries)]

# Save the filtered dataset as a new CSV file.
filtered_dataset.to_csv('/content/drive/MyDrive/Assignment1/south_asia_dataset.csv', index=False)

# Show the filtered dataset
filtered_dataset
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# **Task- 2- Composite Score Ranking:**

# %% [markdown]
# Tasks:
#
#  1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
#  following metrics:
#
#  Composite Score = 0.40 × GDP per Capita+0.30 × Social Support + 0.30 ×  Healthy Life Expectancy
#
#  2. Rank the South Asian countries based on the Composite Score in descending order.
#
#  3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
#
#  4. Discuss whether the rankings based on the Composite Score align with the original Score- support your
#  discussion with some visualization plot.

# %%
import pandas as pd
dataset = filtered_dataset
#Create a new Dataframe
SouthAsia = pd.DataFrame(dataset)

#Compute the Composite Score.
SouthAsia['Composite Score'] = 0.40 * SouthAsia['Log GDP per capita'] + 0.30 * SouthAsia['Social support'] + 0.30 * SouthAsia['Healthy life expectancy']

#Rank the South Asian countries according to their Composite Score.
SouthAsia = SouthAsia.sort_values(by='Composite Score', ascending=False)
SouthAsia
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 127    Sri Lanka  3.898               1.361           1.179
# 92         Nepal  5.158               0.965           0.990
# 125        India  4.054               1.166           0.653
# 107     Pakistan  4.657               1.069           0.600
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 127                    0.586                         0.583       0.144
# 92                     0.443                         0.653       0.209
# 125                    0.417                         0.767       0.174
# 107                    0.321                         0.542       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %%
#Generate a horizontal bar chart displaying the top 5 countries based on their Composite Score.
plt.figure(figsize=(10, 6))
top_5_countries= SouthAsia.head(5)
sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, palette='viridis')
plt.title('Top 5 Countries by Composite Score')
plt.xlabel('Composite Score')
plt.ylabel('Country')
plt.show()
# Out:
# <ipython-input-18-b4b2f7bd8c30>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Composite Score', y='Country name', data=top_5_countries, palette='viridis')

# %%
#Compare the rankings of countries based on the Composite Score.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='score', y='Composite Score', data=SouthAsia, hue = 'Country name' , palette = 'tab10', s=100)
plt.title('Ranking Comparison: Original Score vs. Composite Score')
plt.xlabel('Original Score')
plt.ylabel('Composite Score')
plt.legend(title='Country', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()


#analysis of the findings.
alignment = SouthAsia[['Country name', 'score', 'Composite Score']]
print("Review the rankings:\n", alignment)
# Out:
# Review the rankings:
#      Country name  score  Composite Score
# 127    Sri Lanka  3.898           1.0739
# 92         Nepal  5.158           0.8159
# 125        India  4.054           0.7874
# 107     Pakistan  4.657           0.7039
# 128   Bangladesh  3.886           0.6774
# 142  Afghanistan  1.721           0.3238

# %% [markdown]
# Task - 3 **bold text**- Outlier Detection:

# %% [markdown]
#  Tasks:
#
#  1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
#
#  2. Define outliers using the 1.5 × IQR rule.
#
#  3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
#  in a different color.
#
#  4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#Identify the outlier countries in South Asia based on their Score and GDP per Capita.

SouthAsia = pd.read_csv('/content/drive/MyDrive/Assignment1/south_asia_dataset.csv')

#Calculate the Interquartile Range (IQR) for 'Score' and 'GDP per Capita'.
score_IQR = SouthAsia['score'].quantile(0.75) - SouthAsia['score'].quantile(0.25)
gdp_IQR = SouthAsia['Log GDP per capita'].quantile(0.75) - SouthAsia['Log GDP per capita'].quantile(0.25)

# Calculate the lower and upper bounds for both 'Score' and 'GDP per Capita' using the 1.5 * IQR rule to identify potential outliers.
score_lower_bound = SouthAsia['score'].quantile(0.25) - 1.5 * score_IQR
score_upper_bound = SouthAsia['score'].quantile(0.75) + 1.5 * score_IQR

gdp_lower_bound = SouthAsia['Log GDP per capita'].quantile(0.25) - 1.5 * gdp_IQR
gdp_upper_bound = SouthAsia['Log GDP per capita'].quantile(0.75) + 1.5 * gdp_IQR

#Detect outliers in 'Score' and 'GDP per Capita' using the IQR bounds.
outliers = SouthAsia[(SouthAsia['score'] < score_lower_bound) |
                     (SouthAsia['score'] > score_upper_bound) |
                     (SouthAsia['Log GDP per capita'] < gdp_lower_bound) |
                     (SouthAsia['Log GDP per capita'] > gdp_upper_bound)
                     ]
# Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis.
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Log GDP per capita', y='score', data=SouthAsia, color='blue', label='All Countries')
sns.scatterplot(x='Log GDP per capita', y='score', data=outliers, color='red', label='Outliers')
plt.title('Outlier Detection in South Asia')
plt.xlabel('Log GDP per Capita')
plt.ylabel('Score')


plt.legend()
plt.show()

# Discuss the characteristics of outliers and how they might impact the analysis.
print("Outlier Countries:")
outlier_countries = (outliers[['Country name', 'Log GDP per capita', 'score']])
outlier_countries
# Out:
# Outlier Countries:
#   Country name  Log GDP per capita  score
# 5  Afghanistan               0.628  1.721

# %% [markdown]
# While looking at the outliers ,I came across some surprising findings:
#
# GDP vs Happiness:Some countries have high GDPs but surprisingly low happiness scores, which doesn't fit the usual link between wealth and well-being.
# Unexpected Happiness:On the other hand, some countries have higher happiness scores than their GDP would suggest, possibly due to factors like effective government ,strong social bonds, or issues like corruption or unregulated growth.
# These outliers can really mess with the overall data and make it hard to see the true patterns. Including them can skew averages and give a misleading picture ,reinforcing the idea that money alone doesn’t guarantee happiness.
#
# ---------------------------------------------------------------------------

# %% [markdown]
# **Task - 4 - Exploring Trends Across Metrics:**

# %% [markdown]
#  Tasks:
#
#  1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
#  {pearson correlation} with the Score for South Asian countries.
#
#  2. Create scatter plots with trendlines for these metrics against the Score.
#
#  3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
#  South Asian countries.

# %%
import pandas as pd
SouthAsia = pd.read_csv('/content/drive/MyDrive/Assignment1/south_asia_dataset.csv')

#Calculate the correlation between GDP per Capita and Score for South Asian countries.
correlation_freedom = SouthAsia['score'].corr(SouthAsia['Freedom to make life choices'])
correlation_generosity = SouthAsia['score'].corr(SouthAsia['Generosity'])


#Create scatter plots with trendlines for GDP per Capita and other metrics against the Score.
plt.figure(figsize=(10, 6))
sns.regplot(x='Freedom to make life choices', y='score', data=SouthAsia, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Correlation between Freedom to Make Life Choices and Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()

plt.figure(figsize=(10, 6))
sns.regplot(x='Generosity', y='score', data=SouthAsia, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
plt.title('Correlation between Generosity and Score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.show()

# Identify and discuss the strongest and weakest relationships between GDP per Capita, other metrics, and the Score for South Asian countries.

if abs(correlation_freedom) > abs(correlation_generosity):
    print("The strongest relationship is with Freedom to Make Life Choices:", correlation_freedom)
else:
    print("The strongest relationship is with Generosity:", correlation_generosity)

if correlation_freedom < 0.5:
    print("The relation between Freedom to make Life chocies and score is strong :", correlation_freedom)

elif correlation_freedom > 0.2:
    print("The relation between Freedom to make Life chocies and score is moderate ::", correlation_freedom)

else:
    print("The relation between Freedom to make Life chocies and score is weak ::", correlation_freedom)

if correlation_generosity< 0.5:
    print("The relation between Generosity and score is strong :", correlation_generosity)

elif correlation_generosity > 0.2:
    print("The relation between Generosity and score is moderate ::", correlation_generosity)

else:
    print("The relation between Generosity and score is weak ::", correlation_generosity)
# Out:
# The strongest relationship is with Generosity: 0.874512371253192
# The relation between Freedom to make Life chocies and score is moderate :: 0.8005185224163315
# The relation between Generosity and score is moderate :: 0.874512371253192

# %% [markdown]
# The Pearson correlation analysis shows how "Freedom to Make Life Choices" and "Generosity" relate to happiness in South Asia:
#
# Freedom and Happiness: Countries where people have more freedom tend to have higher happiness scores.
# Generosity: The link between generosity and happiness is weaker in South Asia, with socio-economic factors like social support and economic imbalance playing a bigger role.
# Overall Insight: While generosity has some impact, improving freedom and addressing socio-economic issues would likely have a stronger effect on boosting happiness.
# This means that policies should focus on increasing freedom and improving economic and social conditions to enhance happiness.

# %% [markdown]
# ** Task- 5- Gap Analysis:**

# %% [markdown]
#  Tasks:
#
#  1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
#  for each South Asian country.
#
#  2. Rank the South Asian countries by this gap in both ascending and descending order.
#
#  3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
#
#  4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
# Add a new column called 'GDP - Score' to the dataset.
SouthAsia['GDP-Score Gap'] = SouthAsia['Log GDP per capita'] - SouthAsia['score']

#Rank the countries by the 'GDP - Score' gap, sorting in ascending order.
SouthAsia_asc = SouthAsia.sort_values(by = 'GDP-Score Gap', ascending = True)
Result_asc = SouthAsia_asc[['Country name', 'GDP-Score Gap']]
Result_asc
# Out:
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888
# 4   Bangladesh         -2.764
# 3    Sri Lanka         -2.537
# 5  Afghanistan         -1.093

# %%
#Rank the countries by the 'GDP - Score' gap, sorting in descending order.
SouthAsia_asc = SouthAsia.sort_values(by = 'GDP-Score Gap', ascending = False)
Result_dsc = SouthAsia_asc[['Country name', 'GDP-Score Gap']]
Result_dsc
# Out:
#   Country name  GDP-Score Gap
# 5  Afghanistan         -1.093
# 3    Sri Lanka         -2.537
# 4   Bangladesh         -2.764
# 2        India         -2.888
# 1     Pakistan         -3.588
# 0        Nepal         -4.193

# %%
# Get the top 3 countries with the highest and lowest 'GDP - Score' gaps.
top_3_positive = SouthAsia.head(3)
top_3_negative = SouthAsia.tail(3)

# Combine the necessary data for plotting the top 3 positive and negative 'GDP - Score' gaps.
highlighted_gaps = pd.concat([top_3_positive, top_3_negative])

# generate the bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x='GDP-Score Gap', y='Country name', data=highlighted_gaps, palette=['green']*3 + ['red']*3)
plt.title('Top 3 Countries with the Largest Positive and Negative GDP-Score Gaps')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-858f5754c06b>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='GDP-Score Gap', y='Country name', data=highlighted_gaps, palette=['green']*3 + ['red']*3)

# %%
#Analyze the reasons behind the 'GDP - Score' gaps and discuss their implications for South Asian countries.

print("\n Top three countries with Largets Positive GDP - Score Gaps:")
print(top_3_positive[['Country name', 'GDP-Score Gap']])

print("\n Top three countries with Largets Negative GDP - Score Gaps:")
print(top_3_negative[['Country name', 'GDP-Score Gap']])

#Identify the possible factors contributing to these gaps:
print('\n Analysis of gaps:')
for idx, row in top_3_positive.iterrows():
  print(f"\nCountry: {row['Country name']}")
  print(f"GDP per Capita: {row['Log GDP per capita']}, score: {row['score']}")
  print(f"GDP-Score Gap: {row['GDP-Score Gap']}")
  print("Possible reason for gap: The country's GDP per Capita is much higher than its Composite Score, "
          "indicating that factors such as income inequality, social support, or life expectancy may not "
          "be as favorable despite higher economic output.")

for idx, row in top_3_negative.iterrows():
  print(f"\nCountry: {row['Country name']}")
  print(f"GDP per Capita: {row['Log GDP per capita']}, score: {row['score']}")
  print(f"GDP-Score Gap: {row['GDP-Score Gap']}")
  print("Possible reason for gap: The country's GDP per Capita is significantly lower than its Composite Score, "
          "indicating that factors such as better social support, healthcare, or life expectancy might be "
          "compensating for the lower income levels.")
# Out:
#  Top three countries with Largets Positive GDP - Score Gaps:
#   Country name  GDP-Score Gap
# 0        Nepal         -4.193
# 1     Pakistan         -3.588
# 2        India         -2.888
#
#  Top three countries with Largets Negative GDP - Score Gaps:
#   Country name  GDP-Score Gap
# 3    Sri Lanka         -2.537
# 4   Bangladesh         -2.764
# 5  Afghanistan         -1.093
#
#  Analysis of gaps:
#
# Country: Nepal
# GDP per Capita: 0.965, score: 5.158
# GDP-Score Gap: -4.1930000000000005
# Possible reason for gap: The country's GDP per Capita is much higher than its Composite Score, indicating that factors such as income inequality, social support, or life expectancy may not be as favorable despite higher economic output.
#
# Country: Pakistan
# GDP per Capita: 1.069, score: 4.657
# GDP-Score Gap: -3.588
# ...

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:

# %% [markdown]
# Task - 1- Setup Task - Preparing the Middle Eastern Dataset:

# %% [markdown]
# Tasks:
#
#  1. Similar in Task- 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
#  following list:
#
#
#  middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
#  "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#  "United Arab Emirates", "Yemen"]

# %% [markdown]
#  1. Descriptive Statistics:
#
#  • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
#
#  • Which region has higher happiness Scores on average?

# %%
import pandas as pd

dataset = pd.read_csv('/content/drive/MyDrive/Assignment1/WHR-2024-5CS037.csv')
SouthAsia = pd.read_csv('/content/drive/MyDrive/Assignment1/south_asia_dataset.csv')
middle_east_countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan", "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
filtered_dataset = dataset[dataset['Country name'].isin(middle_east_countries)]

#Store the filtered data as a new CSV file.
filtered_dataset.to_csv('/content/drive/MyDrive/Assignment1/MiddleEastt.csv')
MiddleEast = pd.DataFrame(filtered_dataset)
# Show the filtered dataset
MiddleEast
# Out:
#              Country name  score  Log GDP per capita  Social support  \
# 4                  Israel  7.341               1.803           1.513
# 12                 Kuwait  6.951               1.845           1.364
# 21   United Arab Emirates  6.733               1.983           1.164
# 27           Saudi Arabia  6.594               1.842           1.361
# 61                Bahrain  5.959                 NaN             NaN
# 91                   Iraq  5.166               1.249           0.996
# 99                   Iran  4.923               1.435           1.136
# 124                Jordan  4.186               1.262           0.983
# 132                 Yemen  3.561               0.671           1.281
# 141               Lebanon  2.707               1.377           0.577
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                      0.740                         0.641       0.153
# ...

# %%
#Compute the mean and standard deviation.
mean_score_south_asia = SouthAsia['score'].mean()
std_score_south_asia = SouthAsia['score'].std()

mean_score_middle_east = MiddleEast['score'].mean()
std_score_middle_east = MiddleEast['score'].std()

print(f"Mean Score (South Asia): {mean_score_south_asia:.2f}")
print(f"\nStandard Deviation (South Asia): {std_score_south_asia:.2f}")

print(f"\nMean Score (Middle East): {mean_score_middle_east:.2f}")
print(f"\nStandard Deviation (Middle East): {std_score_middle_east:.2f}")
# Out:
# Mean Score (South Asia): 3.90
#
# Standard Deviation (South Asia): 1.18
#
# Mean Score (Middle East): 5.41
#
# Standard Deviation (Middle East): 1.57

# %%
#Analyzing the mean scores for comparison.
if mean_score_south_asia > mean_score_middle_east:
    print("South Asia has higher happiness scores on average.")
else:
    print("Middle East has higher happiness scores on average.")
# Out:
# Middle East has higher happiness scores on average.

# %% [markdown]
#  2. Top and Bottom Performers:
#
#  • Identify the top 3 and bottom 3 countries in each region based on the score.
#
#  • Plot bar charts comparing these charts.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Identifying the top 3 and bottom 3 countries based on scores in South Asia
top_3_south_asia = SouthAsia.nlargest(3, 'score')
bottom_3_south_asia = SouthAsia.nsmallest(3, 'score')

# Identifying the top 3 and bottom 3 countries based on scores in the Middle East
top_3_middle_east = MiddleEast.nlargest(3, 'score')
bottom_3_middle_east = MiddleEast.nsmallest(3, 'score')

# Creating a figure with subplots for the bar charts comparison
fig, axes = plt.subplots(2, 2, figsize = (14, 11))

# Bar chart for the top performers in South Asia
axes[0, 0].barh(top_3_south_asia['Country name'], top_3_south_asia['score'], color = 'grey')
axes[0, 0].set_title('Top 3 Countries (South Asia)')
axes[0, 0].set_xlabel('Score')
axes[0, 0].set_ylabel('Country')
axes[0, 0].invert_yaxis()

# Bar chart for the bottom performers in South Asia
axes[0, 1].barh(bottom_3_south_asia['Country name'], bottom_3_south_asia['score'], color = 'skyblue')
axes[0, 1].set_title('Bottom 3 Countries (South Asia)')
axes[0, 1].set_xlabel('Score')
axes[0, 1].invert_yaxis()

# Bar chart for the top performers in the Middle East
axes[1, 0].barh(top_3_middle_east['Country name'], top_3_middle_east['score'], color = 'lightcoral')
axes[1, 0].set_title('Top 3 Countries (Middle East)')
axes[1, 0].set_xlabel('Score')
axes[1, 0].set_ylabel('Country')
axes[1, 0].invert_yaxis()

# Bar chart for the bottom performers in the Middle East
axes[1, 1].barh(bottom_3_middle_east['Country name'], bottom_3_middle_east['score'], color = 'mediumseagreen')
axes[1, 1].set_title('Bottom 3 Countries (Middle East)')
axes[1, 1].set_xlabel('Score')
axes[1, 1].invert_yaxis()

# Adjusting the layout for a better view
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
#
#  • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
#  between the regions using grouped bar charts.
#
#  • Which metrics show the largest disparity between the two regions?

# %%
import pandas as pd
import numpy as np

# Calculate the average values of key metrics for each region (South Asia and Middle East)
metrics = ['Log GDP per capita', 'Social support', 'Healthy life expectancy']
mean_values_south_asia = SouthAsia[metrics].mean()
mean_values_middle_east = MiddleEast[metrics].mean()

# Define the positions for the bars on the x-axis
x = np.arange(len(metrics))
width = 0.35  # Set the width of the bars

# Create the plot with a specific figure size
fig, ax = plt.subplots(figsize = (10, 6))

# Create bars for the South Asia and Middle East average values
bar1 = ax.bar(x - width/2, mean_values_south_asia, width, label = 'South Asia', color ='red')
bar2 = ax.bar(x + width/2, mean_values_middle_east, width, label = 'Middle East', color = 'green')

# Add labels for the x-axis, y-axis, and the title
ax.set_xlabel('Metrics')
ax.set_ylabel('Average Values')
ax.set_title('Average Values of Key Metrics Between South Asia and the Middle East')

# Set x-axis tick labels to correspond with the metric names
ax.set_xticks(x)
ax.set_xticklabels(metrics)

# Annotate each bar with its corresponding value
for bar in bar1:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():.2f}', ha='center', va='bottom')

for bar in bar2:
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(), f'{bar.get_height():.2f}', ha='center', va='bottom')

# Adjust the layout to ensure everything fits nicely
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
#  4. Happiness Disparity:
#
#  • Compute the range (max- min) and coefficient of variation (CV) for Score in both regions.
#
#  • Which region has greater variability in happiness?

# %%
import pandas as pd

# Calculate the range (difference between max and min score) for each region
range_south_asia = SouthAsia['score'].max() - SouthAsia['score'].min()
range_middle_east = MiddleEast['score'].max() - MiddleEast['score'].min()

# Calculate the mean and standard deviation for each region
mean_south_asia = SouthAsia['score'].mean()
std_south_asia = SouthAsia['score'].std()

mean_middle_east = MiddleEast['score'].mean()
std_middle_east = MiddleEast['score'].std()

# Calculate the Coefficient of Variation (CV) for each region (std/mean * 100)
cv_south_asia = (std_south_asia / mean_south_asia) * 100
cv_middle_east = (std_middle_east / mean_middle_east) * 100

# Display the results for both regions
print("South Asia Happiness Disparity:")
print(f"Range: {range_south_asia}")
print(f"Coefficient of Variation (CV): {cv_south_asia:.2f}%")

print("\nMiddle East Happiness Disparity:")
print(f"Range: {range_middle_east}")
print(f"Coefficient of Variation (CV): {cv_middle_east:.2f}%")

# Compare the variability between the two regions based on CV
if cv_south_asia > cv_middle_east:
    print("\nSouth Asia has greater variability in happiness.")
elif cv_south_asia < cv_middle_east:
    print("\nMiddle East has greater variability in happiness.")
# Out:
# South Asia Happiness Disparity:
# Range: 3.4370000000000003
# Coefficient of Variation (CV): 30.21%
#
# Middle East Happiness Disparity:
# Range: 4.634
# Coefficient of Variation (CV): 28.94%
#
# South Asia has greater variability in happiness.

# %% [markdown]
#  5. Correlation Analysis:
#
#  • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and Generosity within each region.
#
#  • Create scatter plots to visualize and interpret the relationships.

# %%
import seaborn as sns

# Calculate the correlation between Score and Freedom to Make Life Choices for South Asia and Middle East
correlation_south_asia_freedom = SouthAsia['score'].corr(SouthAsia['Freedom to make life choices'])
correlation_middle_east_freedom = MiddleEast['score'].corr(MiddleEast['Freedom to make life choices'])

# Calculate the correlation between Score and Generosity for South Asia and Middle East
correlation_south_asia_generosity = SouthAsia['score'].corr(SouthAsia['Generosity'])
correlation_middle_east_generosity = MiddleEast['score'].corr(MiddleEast['Generosity'])

# Print the correlation results for both regions and metrics
print(f"Correlation between Score and Freedom to Make Life Choices in South Asia: {correlation_south_asia_freedom:.2f}")
print(f"Correlation between Score and Freedom to Make Life Choices in Middle East: {correlation_middle_east_freedom:.2f}")

print(f"\nCorrelation between Score and Generosity in South Asia: {correlation_south_asia_generosity:.2f}")
print(f"Correlation between Score and Generosity in Middle East: {correlation_middle_east_generosity:.2f}")

# Create scatter plots to visualize the relationship between Score and other metrics in South Asia
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(data=SouthAsia, x='Freedom to make life choices', y='score', color='blue', label='South Asia')
sns.regplot(data=SouthAsia, x='Freedom to make life choices', y='score', scatter=False, color='blue', label='Regression Line')
plt.title('South Asia: Score vs Freedom')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.legend()

# Scatter plot for Score vs Generosity in South Asia
plt.subplot(1, 2, 2)
sns.scatterplot(data=SouthAsia, x='Generosity', y='score', color='green', label='South Asia')
sns.regplot(data=SouthAsia, x='Generosity', y='score', scatter=False, color='green', label='Regression Line')
plt.title('South Asia: Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.legend()

plt.tight_layout()
plt.show()

# Create scatter plots for the Middle East region
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(data=MiddleEast, x='Freedom to make life choices', y='score', color='red', label='Middle East')
sns.regplot(data=MiddleEast, x='Freedom to make life choices', y='score', scatter=False, color='red', label='Regression Line')
plt.title('Middle East: Score vs Freedom')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.legend()

# Scatter plot for Score vs Generosity in the Middle East
plt.subplot(1, 2, 2)
sns.scatterplot(data=MiddleEast, x='Generosity', y='score', color='orange', label='Middle East')
sns.regplot(data=MiddleEast, x='Generosity', y='score', scatter=False, color='orange', label='Regression Line')
plt.title('Middle East: Score vs Generosity')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Correlation between Score and Freedom to Make Life Choices in South Asia: 0.80
# Correlation between Score and Freedom to Make Life Choices in Middle East: 0.86
#
# Correlation between Score and Generosity in South Asia: 0.87
# Correlation between Score and Generosity in Middle East: 0.63

# %% [markdown]
#  6. Outlier Detection:
#
#  • Identify outlier countries in both regions based on Score and GDP per Capita.
#
#  • Plot these outliers and discuss their implications.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the datasets for South Asia and the Middle East
MiddleEast = pd.read_csv('/content/drive/MyDrive/Assignment1/MiddleEastt.csv')
SouthAsia = pd.read_csv('/content/drive/MyDrive/Assignment1/south_asia_dataset.csv')

# Function to identify outliers in a given column using IQR (Interquartile Range)
def find_outliers(data, column):
    Q1 = data[column].quantile(0.25)  # 25th percentile (Q1)
    Q3 = data[column].quantile(0.75)  # 75th percentile (Q3)
    IQR = Q3 - Q1  # Calculate the Interquartile Range (IQR)
    lower_bound = Q1 - 1.5 * IQR  # Lower bound for detecting outliers
    upper_bound = Q3 + 1.5 * IQR  # Upper bound for detecting outliers
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]  # Identify outliers
    return outliers

# Detect outliers in South Asia for both 'score' and 'Log GDP per capita'
outliers_south_asia = find_outliers(SouthAsia, 'score')
outliers_south_asia_gdp = find_outliers(SouthAsia, 'Log GDP per capita')

# Detect outliers in the Middle East for both 'score' and 'Log GDP per capita'
outliers_middle_east = find_outliers(MiddleEast, 'score')
outliers_middle_east_gdp = find_outliers(MiddleEast, 'Log GDP per capita')

# Combine the outliers detected for both metrics in each region
south_asia_outliers = pd.concat([outliers_south_asia, outliers_south_asia_gdp]).drop_duplicates()
middle_east_outliers = pd.concat([outliers_middle_east, outliers_middle_east_gdp]).drop_duplicates()

# Scatter plot for South Asia showing outliers
plt.figure(figsize=(10, 6))
plt.scatter(data = SouthAsia, x='Log GDP per capita', y = 'score', color='blue', label='South Asia')  # Plot all data points
plt.scatter(data = south_asia_outliers, x = 'Log GDP per capita', y = 'score', color='red', label='Outliers', s = 100)  # Highlight outliers in red
plt.title('South Asia: Outliers in Score vs Log GDP per capita')
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.legend()
plt.show()

# Scatter plot for the Middle East showing outliers
plt.figure(figsize=(10, 6))
plt.scatter(data = MiddleEast, x='Log GDP per capita', y = 'score', color='green', label='Middle East')  # Plot all data points
plt.scatter(data = middle_east_outliers, x = 'Log GDP per capita', y = 'score', color='red', label='Outliers', s = 100)  # Highlight outliers in red
plt.title('Middle East: Outliers in Score vs Log GDP per capita')
plt.xlabel('Log GDP per capita')
plt.ylabel('Score')
plt.legend()
plt.show()

# Print outliers for review: South Asia
print("Outliers for South Asia:")
print(south_asia_outliers[['Country name', 'score', 'Log GDP per capita']])

# Print outliers for review: Middle East
print("\nOutliers for Middle East:")
print(middle_east_outliers[['Country name', 'score', 'Log GDP per capita']])
# Out:
# Outliers for South Asia:
#   Country name  score  Log GDP per capita
# 5  Afghanistan  1.721               0.628
#
# Outliers for Middle East:
# Empty DataFrame
# Columns: [Country name, score, Log GDP per capita]
# Index: []

# %% [markdown]
# 7. Visualization:
#
#  • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
#
#  • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
# Combine South Asia and Middle East datasets for comparison
# Add a new column 'Region' to each dataset to indicate the region
combined_data = pd.concat([
    SouthAsia[['Country name', 'score']].assign(Region = 'South Asia'),  # Add 'Region' column for South Asia
    MiddleEast[['Country name', 'score']].assign(Region = 'Middle East')  # Add 'Region' column for Middle East
])

# Create a boxplot to compare scores between the two regions
plt.figure(figsize=(10, 6))
sns.boxplot(data=combined_data, x='Region', y='score', palette='Set2', width=0.6)  # Boxplot comparing score distribution

# Add title and axis labels to the plot for clarity
plt.title('Boxplot Comparison of Scores: South Asia vs Middle East', fontsize=14)
plt.xlabel('Region', fontsize=12)  # X-axis label: Region
plt.ylabel('Score', fontsize=12)   # Y-axis label: Score

# Enhance the plot with a grid for better visualization of the y-axis
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to avoid overlapping elements
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <ipython-input-34-5e87ece229e8>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=combined_data, x='Region', y='score', palette='Set2', width=0.6)  # Boxplot comparing score distribution

# %% [markdown]
# The boxplot paints a clearer picture of the happiness scores in South Asia and the Middle East:
#
# Median Score: The Middle East tends to have higher happiness scores on average, with its median score being noticeably higher than that of South Asia.
# Spread of Scores: South Asia’s scores are more tightly grouped together, suggesting a more consistent experience of happiness across countries. On the other hand, the Middle East has a wider spread, indicating greater diversity in happiness levels.
# Outliers: South Asia stands out with a country that has an unusually low happiness score, while the Middle East doesn’t show any such extreme values.
# Overall Comparison: The Middle East has both higher and more varied happiness scores, whereas South Asia’s scores are more concentrated at the lower end, pointing to less variation and generally lower levels of happiness.
