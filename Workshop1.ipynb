# %% [markdown]
# <a href="https://colab.research.google.com/github/sadichyaa/Assesment1/blob/main/Workshop1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from PIL import Image
# display image in colab
image_gray = Image . open ("/content/drive/MyDrive/AIML/Data/cameraman.png")
gif = Image . open ("/content/drive/MyDrive/AIML/Data/lena_gray.gif")
display ( image_gray )
display ( gif )
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x512>
# <PIL.GifImagePlugin.GifImageFile image mode=P size=512x512>

# %%
from PIL import Image
# display image in colab
image_grayed = Image . open ("/content/drive/MyDrive/AIML/Data/lena_gray.gif")
display ( image_grayed )
# Out:
# <PIL.GifImagePlugin.GifImageFile image mode=P size=512x512>

# %%
from PIL import Image
# display image in colab
image_colored = Image . open ("/content/drive/MyDrive/AIML/Data/images.jpg")
display ( image_colored )
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=235x215>

# %%
print ( " Image Format : " , image_gray . format )
print ( " Image Size : " , image_gray . size )
print ( " Image Mode : " , image_gray . mode )
# Out:
#  Image Format :  PNG
#  Image Size :  (512, 512)
#  Image Mode :  L

# %%
print ( " Image Format : " , image_grayed . format )
print ( " Image Size : " , image_grayed . size )
print ( " Image Mode : " , image_grayed . mode )
# Out:
#  Image Format :  GIF
#  Image Size :  (512, 512)
#  Image Mode :  P

# %%
# Get the size (width , height ) and channels (RGB)
width , height = image_gray . size
channels = len( image_gray . getbands () )
print ( f" Image shape (RGB): ({ height } , { width } , { channels
})")
image_size_gray = width * height *3
print ( f" Image size (RGB): { image_size_gray }")
# Out:
#  Image shape (RGB): (512 , 512 , 1)
#  Image size (RGB): 786432

# %%
# Get the size (width , height ) and channels (RGB)
width , height = image_grayed . size
channels = len( image_grayed . getbands () )
print ( f" Image shape (RGB): ({ height } , { width } , { channels
})")
image_size_grayed = width * height *1
print ( f" Image size (RGB): { image_size_grayed }")
# Out:
#  Image shape (RGB): (512 , 512 , 1)
#  Image size (RGB): 262144

# %%
import numpy as np

# %%
# Convert the Pillow image to a NumPy array
image_array_gray = np . array ( image_gray )
# Display the shape of the NumPy array (height , width ,channels )
print (" Shape of the image array :", image_array_gray .shape )
# Out:
#  Shape of the image array : (512, 512)

# %%
# Convert the Pillow image to a NumPy array
image_array_grayed = np . array ( image_grayed )
# Display the shape of the NumPy array (height , width ,channels )
print (" Shape of the image array :", image_array_grayed .
shape )
# Out:
#  Shape of the image array : (512, 512)

# %%
# Convert the Pillow image to a NumPy array
image_array_colored = np . array ( image_colored )
# Display the shape of the NumPy array (height , width ,channels )
print (" Shape of the image array :", image_array_colored . shape
)
#For Red Channels
red_channel = image_array_colored [: , : , 0] # Red channel
print ( red_channel )
display ( red_channel )
# For Green Channels
green_channel = image_array_colored [: , : , 0] # Greenchannel
print ( green_channel )
display ( green_channel )
# Out:
#  Shape of the image array : (215, 235, 3)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# For Blue Channel :
blue_channel = image_array_colored [: , : , 2] # Blue channel
print ( blue_channel )
display ( blue_channel )
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# For Blue Channel :
blue_channel = image_array_colored [: , : , 2] # Blue channel
print ( blue_channel )
display ( blue_channel )
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
# Assuming image_colored is already defined and loaded above
# Get the R, G, and B channels
r , g , b = image_colored . split ()
# Display or further process the individual channels
display ( r )
display ( g )
display ( b )
# Out:
# <PIL.Image.Image image mode=L size=235x215>
# <PIL.Image.Image image mode=L size=235x215>
# <PIL.Image.Image image mode=L size=235x215>

# %%
# Sample Implementation :
# Accessing a specific row - 100 th row
row_100 = image_array_colored [100 , : , :]
# Accessing a specific column - 50 th col
col_50 = image_array_colored [: , 50 , :]
# Accessing a specific pixel (row 10 , col 20)
pixel = image_array_colored [10 , 20 , :] # Gets RGB values at (10 ,20)

print(f"Row 100 shape: {row_100.shape}")
print(f"Column 50 shape: {col_50.shape}")
print(f"Pixel at (10, 20): {pixel}")
# Out:
# Row 100 shape: (235, 3)
# Column 50 shape: (215, 3)
# Pixel at (10, 20): [255 255 255]

# %%
# Define the cropping box (left, upper, right, lower)
left = 100
upper = 50
right = 200
lower = 150
# Crop the image
cropped_image = image_colored.crop((left, upper, right, lower))
# Display the cropped image
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
# Create a NumPy array (Here , we use a dummy array for illustration )
image_array = np . zeros ((100 , 100 , 3) , dtype = np . uint8 ) #Example : black image
# Convert the NumPy array back to a Pillow Image object
image_from_array = Image . fromarray ( image_array )
# Display the image
# image_from_array . show () # This typically requires an image viewer, which might not be configured in Colab.
# Optionally save the image to a file
image_from_array . save ("output_image.jpg")
